# %% [raw]
# ---
# title: Vancouver Development Permits
#
# format:
#     html:
#         toc: true
#         code-tools: true
# ---

# %% [markdown]
# ## Walkthrough of process
#
# ### Overview
# First I searched for open data. Many regions across Canada release data on systems like the [Open Government Data Portal](https://search.open.canada.ca/data/). BC has [one](https://catalogue.data.gov.bc.ca/) and Vancouver has [one](https://opendata.vancouver.ca/pages/home/).
#
# The Vancouver data hub had one [dataset](#open-data-portal) but it only included building permits. As these are different from development permits, I continued my search.
#
# Next, I searched directly for development permits in Vancouver. I found the [Shape your city](#shape-your-city) page. This was missing a lot of info.
#
# Finally, I dug around with any construction permits in Vancouver and noticed that you could [search for building permits](https://plposweb.vancouver.ca/Public/Default.aspx?PosseMenuName=PC_Search). That [search page](#city-of-vancouver-services) contained other types of permits including development permits.
#
#
# ### Open Data Portal
# Vancouver has an open data portal. This is available via an [api](https://opendata.vancouver.ca/explore/dataset/issued-building-permits/api/?dataChart=...%3D%3D)
#
# This contains only building permits and only issued permits. **Doesn't work for our purposes**. Maybe useful elsewhere.
#
# #### Schema:
# ```Json
# {
#
#     "permitnumber":"DB-2016-01042",
#     "permitnumbercreateddate":"2016-07-12",
#     "issuedate":"2017-01-26",
#     "permitelapseddays":198,
#     "projectvalue":15000,
#     "typeofwork":"Demolition / Deconstruction",
#     "address":"2380 E 53RD AVENUE, Vancouver, BC V5S 1V8",
#     "projectdescription":"Low Density Housing - Demolition / Deconstruction - To demolish the existing one family dwelling building ($15,000) on this site.",
#     "permitcategory":null,
#     "applicant":"Dinkar Wason DBA: Yuvraj Properties Ltd",
#     "applicantaddress":"2380 E 53rd Ave Vancouver, BC V5S1V8",
#     "propertyuse":[
#         "Dwelling Uses"
#     ]
#     ,
#     "specificusecategory":[
#         "Single Detached House w/Sec Suite"
#     ]
#     ,
#     "buildingcontractor":"All Right Trucking 99 Ltd",
#     "buildingcontractoraddress":null,
#     "issueyear":"2017",
#     "geolocalarea":"Victoria-Fraserview",
#     "geom":{
#         "type":"Feature",
#         "geometry":{
#             "coordinates":[
#                 -123.0581336,
#                 49.2210845
#             ]
#             ,
#             "type":"Point"
#         }
#         ,
#         "properties":{
#         }
#     }
#     ,
#     "yearmonth":"2017-01",
#     "geo_point_2d":{
#         "lon":-123.0581336,
#         "lat":49.2210845
#     }
#
# }
# ```
#
# ### Shape your city
# Hub for getting community feedback on projects. https://www.shapeyourcity.ca/development
#
# Does not contain all the information required. Unknown refresh cadence. **Does not work**
#
# ### City Of Vancouver Services
#
# Search page for existing building permits in Vancouver. https://plposweb.vancouver.ca/Public/Default.aspx?PosseMenuName=PC_Search
#
# Searchable by Address, Number, and Date. Contains all sorts of permits including development, building, electrical, gas, fire, Mechanical, and plumbing. Could also be useful elsewhere.
#
# Searching on the 8th of March gave me results for permit applications created that same day.
#
# Searching presents a table such as:
#
# | 	|Type 	| Number 	| Location 	| Status 	| Created Date |	 Issue Date |	Completed Date|
# |---|-------|---------|--------------|----------|-------------|--------------|----------------|
# |[Go to Development Permit]| 	Development Permit| 	DP-2024-00080| 	675 W 10TH AVENUE, Vancouver, BC V5Z 1L3| 	In Review |	Feb 1, 2024 		|
# |[Go to Development Permit]| 	Development Permit| 	DP-2024-00081| 	2856 E 19TH AVENUE, Vancouver, BC V5M 2S7| 	In Review |	Feb 2, 2024 		|
# |[Go to Development Permit]| 	Development Permit| 	DP-2024-00083| 	1875 MAPLE STREET, Vancouver, BC V6J 3S8 |	In Review |	Feb 2, 2024 		|
# |[Go to Development Permit]| 	Development Permit| 	DP-2024-00084| 	3003 W 3RD AVENUE, Vancouver, BC V6K 1M9 |	In Review |	Feb 2, 2024 		|
# |[Go to Development Permit]| 	Development Permit| 	DP-2024-00085| 	1958 W 60TH AVENUE, Vancouver, BC V6P 2B1| 	In Review |	Feb 2, 2024 		|
# |[Go to Development Permit]| 	Development Permit| 	DP-2024-00086| 	1168 E 48TH AVENUE, Vancouver, BC V5W 2E7| 	In Review |	Feb 2, 2024 		|
# |[Go to Development Permit]| 	Development Permit| 	DP-2024-00087| 	688 W HASTINGS STREET, Vancouver, BC V6B 1P1| 	In Review |	Feb 2, 2024 		|
# |[Go to Development Permit]| 	Development Permit| 	DP-2024-00088| 	1138 DAVIE STREET, Vancouver, BC V6E 1N1 |	Issued |Feb 2, 2024 |	Mar 1, 2024 	|
# |[Go to Development Permit]| 	Development Permit| 	DP-2024-00089| 	136 W CORDOVA STREET, Vancouver, BC V6B 1E4| 	Issued| 	Feb 2, 2024 |	Mar 1, 2024 	|
#
# This table contains the **status** and **number**. The first element of a row is a link to the summary for that permit.
#
# On that page we have the **description** and **name**:
#
# ![Snapshot_2024-03-09_15-14-59.png](attachment:c02c5463-d793-47d0-bbd9-d83d383534df.png)

# %% [markdown]
# ## Scraping Data Source
# The usable data source seems to be the City of Vancouver services.
#
# - data is not url encoded
#     - cannot create url to hit for data
# - request seems to be encoded in request
# ```json
#     {
# 	"currentpaneid": "1018439",
# 	"paneid": "987904",
# 	"functiondef": "5",
# 	"sortcolumns": "{}",
# 	"datachanges": "'IExLXUXlhCFH7WLxLBCLTt%',('C','S0',972146,'2024-02-01+00:00:00'),('C','S0',984849,'2024-03-09+00:00:00'),('C','S0',1039023,'Development+Permit'),('C','S0',972146,'2024-02-01+00:00:00'),('C','S0',984849,'2024-03-09+00:00:00'),('F','ext-gen1009',0,0)",
# 	"comesfrom": "posse",
# 	"changesxml": "",
# 	"changespending": "T",
# 	"changesonobject": ""
# }
# ```
# Tuples at the end of the `datachages` field seem to encode the form data but it is not clear which of these map to each of the fields on screen.
#
# Selenium could be used to automate data scraping instead

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import pandas as pd
from time import sleep

driver = webdriver.Chrome()

driver.maximize_window()

driver.get("https://plposweb.vancouver.ca/Public/Default.aspx?PossePresentation=PermitSearchByDate")
from_field = driver.find_element(By.ID, "CreatedDateFrom_1018439_S0")
from_field.send_keys("Jan 1, 2024")
from_field.send_keys(Keys.ENTER)

to_field = driver.find_element(By.ID, "CreatedDateTo_1018439_S0")
to_field.send_keys("Mar 30, 2024")
to_field.send_keys(Keys.ENTER)

type_field = driver.find_element(By.ID, "ObjectDefDescription_1018439_S0")
type_field.send_keys("Development Permit")
type_field.send_keys(Keys.ENTER)

sleep(2)
driver.save_screenshot("test.png")

table = driver.find_element(By.TAG_NAME, "table")

header = table.find_element(By.TAG_NAME, "thead")
header_values = ["link"]
for elem in header.find_elements(By.TAG_NAME, "th")[1:]:
    header_values.append(elem.text)
    
rows = []
for row in table.find_elements(By.TAG_NAME, "tbody")[:-1]:
    cells = row.find_elements(By.TAG_NAME, "td")

    link = cells[0].find_element(By.TAG_NAME, "a").get_dom_attribute("href")
    values = [link]
    values.extend([cell.text for cell in cells[1:]])
    rows.append(values)

df = pd.DataFrame(rows, columns = header_values)

# %%
df
# Out:
#                                                   link                Type  \
# 0    https://plposweb.vancouver.ca/Public/Default.a...  Development Permit
# 1    https://plposweb.vancouver.ca/Public/Default.a...  Development Permit
# 2    https://plposweb.vancouver.ca/Public/Default.a...  Development Permit
# 3    https://plposweb.vancouver.ca/Public/Default.a...  Development Permit
# 4    https://plposweb.vancouver.ca/Public/Default.a...  Development Permit
# ..                                                 ...                 ...
# 118  https://plposweb.vancouver.ca/Public/Default.a...  Development Permit
# 119  https://plposweb.vancouver.ca/Public/Default.a...  Development Permit
# 120  https://plposweb.vancouver.ca/Public/Default.a...  Development Permit
# 121  https://plposweb.vancouver.ca/Public/Default.a...  Development Permit
# 122  https://plposweb.vancouver.ca/Public/Default.a...  Development Permit
#
#             Number                                      Location     Status  \
# 0    DP-2024-00002   1090 W PENDER STREET, Vancouver, BC V6E 2N7  Completed
# 1    DP-2024-00003    983 HELMCKEN STREET, Vancouver, BC V6Z 2S5  In Review
# 2    DP-2024-00004  1115 GRANVILLE STREET, Vancouver, BC V6Z 1M1     Issued
# 3    DP-2024-00005    5504 VICTORIA DRIVE, Vancouver, BC V5P 3W1  In Review
# 4    DP-2024-00007           7474 CULLODEN STREET, Vancouver, BC  In Review
# ..             ...                                           ...        ...
# 118  DP-2024-00164     3250 E 49TH AVENUE, Vancouver, BC V5S 1L3  In Review
# 119  DP-2024-00184      601 KEEFER STREET, Vancouver, BC V6A 3V8  In Review
# 120  DP-2024-00185              388 SLOCAN STREET, Vancouver, BC  In Review
# 121  DP-2024-00193     2929 E 22ND AVENUE, Vancouver, BC V5M 2Y3  In Review
# 122  DP-2024-00197      1807 LARCH STREET, Vancouver, BC V6K 3N9  In Review
#
#      Created Date    Issue Date Completed Date
# 0     Jan 3, 2024  Jan 23, 2024    Feb 1, 2024
# 1     Jan 3, 2024
# 2     Jan 3, 2024  Jan 30, 2024
# 3     Jan 3, 2024
# 4     Jan 5, 2024
# ..            ...           ...            ...
# 118  Feb 29, 2024
# 119   Mar 4, 2024
# 120   Mar 4, 2024
# 121   Mar 6, 2024
# 122   Mar 6, 2024
#
# [123 rows x 8 columns]

# %% [markdown]
# #### Scrapping remaining info

# %%
df["link"][0]
# Out:
# 'https://plposweb.vancouver.ca/Public/Default.aspx?PossePresentation=Guest&PosseObjectId=221425296'

# %% [markdown]
# ![Snapshot_2024-03-09_15-45-56.png](attachment:d1274002-79af-4926-97e7-eb6c2bc6a206.png)
#
# This time the data is encoded in the url. BeutifulSoup can be used to scrape these pages quickly.
